# %%
#imports
import sys
from bs4 import BeautifulSoup
import requests
import pandas
import time

#import selenium to scrap JS generated pages
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait

# %%
def getWeatherForCity(name, lat, long, driver, cities):
    newCity = {}
    newCity['name'] = name
    newCity['lat'] = lat
    newCity['long']= long

    urlPage = "https://cn.bing.com/search?q=" + name + "+china+historical+weather&ensearch=1&FORM=BESBTP"

    #using selenium as a firefox browser


    driver.get(urlPage)
    driver.implicitly_wait(100)



    #scrap the weather data with BS


    content = BeautifulSoup(driver.page_source, "html.parser")
    title = content.find("span", {"class":"b_prominentFocusLabel"})

    timer = 0
    while (title == None and timer < 30):
        time.sleep(1)
        content = BeautifulSoup(driver.page_source, "html.parser")
        title = content.find("span", {"class":"b_prominentFocusLabel"})
        timer = timer + 1



    if(title is not None and name +',' in title.text):

        historical = driver.execute_script("return HistoricalWeather.data.mAvgs;")

        while(historical == {}):
            time.sleep(1)
            historical = driver.execute_script("return HistoricalWeather.data.mAvgs;")

        for i in range(0,12):
            newCity.update(historical[i].copy());
            cities[i].append(newCity.copy())
    else:
        #No weather data
        print("No data for "+ name)
        for i in range(0,12):
            cities[i].append(newCity.copy())

# %%
#setting up selenium driver

driver = webdriver.Firefox()

#initialize citiesList
cities = []
for i in range(0,12):
    cities.append([])

# %%
#get the list of chinese cities from xls file
citiesList = pandas.read_excel("citiesLoc.xlsx", sheetname=0, header=0, index_col=False, keep_default_na=True).to_dict()
# Out:
# No data for Xiling

# %%
#scrapping the data for each city
nbCities = len(citiesList)
i = 0
for cityName, loc in citiesList.items():
    print(str(i)+"/"+str(nbCities))
    getWeatherForCity(cityName, loc[0], loc[1], driver, cities)
    i=i+1
# Out:
# 0/828
# 1/828
# 2/828
# 3/828
# 4/828
# 5/828
# No data for Chadian
# 6/828
# 7/828
# No data for Luxu
# 8/828
# 9/828
# No data for Yanjiang
# 10/828
# No data for Dawukou
# 11/828
# No data for Tianfu
# 12/828
# No data for Qiancheng
# 13/828
# 14/828
# No data for Boli
# 15/828
# No data for Shizilu
# 16/828
# No data for Panshan
# 17/828
# No data for Nanding
# 18/828
# No data for Zhangjiakou Shi Xuanhua Qu
# 19/828
# No data for Xiangyang
# 20/828
# 21/828
# No data for Shilaoren
# 22/828
# No data for Kashgar
# 23/828
# 24/828
# 25/828
# No data for Shahecheng
# 26/828
# 27/828
# No data for Wacheng
# 28/828
# No data for Zhenzhou
# 29/828
# No data for Luocheng
# 30/828
# 31/828
# 32/828
# No data for Dongling
# 33/828
# 34/828
# No data for Huai'an
# 35/828
# 36/828
# No data for Weining
# 37/828
# 38/828
# 39/828
# 40/828
# No data for Dengying
# 41/828
# No data for Kuai’an
# 42/828
# No data for Dongyuan
# 43/828
# 44/828
# 45/828
# 46/828
# No data for Chamdo
# 47/828
# 48/828
# No data for Dazuo
# 49/828
# 50/828
# 51/828
# No data for Qiaojiang
# 52/828
# 53/828
# No data for Qingnian
# 54/828
# 55/828
# 56/828
# 57/828
# No data for Suileng
# 58/828
# 59/828
# 60/828
# 61/828
# No data for Zhenjiang
# 62/828
# 63/828
# No data for Zhaozhou
# 64/828
# No data for Sanshui
# 65/828
# 66/828
# 67/828
# 68/828
# 69/828
# 70/828
# 71/828
# No data for Huicheng
# 72/828
# 73/828
# 74/828
# 75/828
# No data for Nanzhou
# 76/828
# No data for Nancang
# 77/828
# 78/828
# 79/828
# No data for Gucheng Chengguanzhen
# 80/828
# No data for Shangzhi
# 81/828
# 82/828
# No data for Wangqinzhuang
# 83/828
# 84/828
# 85/828
# 86/828
# No data for Tongzhou
# 87/828
# 88/828
# 89/828
# 90/828
# 91/828
# 92/828
# No data for Xiannü
# 93/828
# 94/828
# No data for Mabai
# 95/828
# 96/828
# No data for Hushitai
# 97/828
# 98/828
# 99/828
# No data for Mentougou
# 100/828
# 101/828
# No data for Chaoyang, Jilin
# 102/828
# 103/828
# 104/828
# 105/828
# No data for Shazikou
# 106/828
# 107/828
# 108/828
# 109/828
# No data for Qiongshan
# 110/828
# 111/828
# 112/828
# 113/828
# 114/828
# 115/828
# 116/828
# 117/828
# 118/828
# 119/828
# No data for Huanan
# 120/828
# 121/828
# 122/828
# 123/828
# 124/828
# No data for Xujiaba
# 125/828
# 126/828
# No data for Nangandao
# 127/828
# No data for Lianzhou
# 128/828
# No data for Shengli
# 129/828
# No data for Nenjiang
# 130/828
# 131/828
# No data for Huotong
# 132/828
# 133/828
# 134/828
# 135/828
# No data for Yigou
# 136/828
# 137/828
# No data for Gaozhuang
# 138/828
# 139/828
# No data for Saga
# 140/828
# No data for Jingling
# 141/828
# 142/828
# No data for Huanren
# 143/828
# No data for Longquan
# 144/828
# No data for Hecun
# 145/828
# No data for Tai’an
# 146/828
# 147/828
# No data for Tangkou
# 148/828
# 149/828
# No data for Huaiyuan Chengguanzhen
# 150/828
# No data for Songling
# 151/828
# No data for Wusong
# 152/828
# No data for Danshui
# 153/828
# No data for Shijing
# 154/828
# No data for Fubao
# 155/828
# 156/828
# 157/828
# No data for Jishui
# 158/828
# 159/828
# 160/828
# No data for Shangyu
# 161/828
# No data for Dongcun
# 162/828
# No data for Hede
# 163/828
# 164/828
# No data for Nanrenfu
# 165/828
# No data for Xindi
# 166/828
# 167/828
# 168/828
# 169/828
# No data for Guankou
# 170/828
# No data for Huaicheng
# 171/828
# 172/828
# No data for Yantongshan
# 173/828
# 174/828
# No data for Luofeng
# 175/828
# No data for Dazhong
# 176/828
# 177/828
# 178/828
# No data for Qidu
# 179/828
# 180/828
# No data for Nangong
# 181/828
# 182/828
# No data for Zhangwan
# 183/828
# 184/828
# 185/828
# No data for Shitanjing
# 186/828
# 187/828
# 188/828
# 189/828
# No data for Linghai
# 190/828
# 191/828
# 192/828
# 193/828
# No data for Fuling
# 194/828
# 195/828
# No data for Chenghua
# 196/828
# 197/828
# 198/828
# 199/828
# 200/828
# No data for Hongqiao
# 201/828
# No data for Mizhou
# 202/828
# 203/828
# No data for Xiacang
# 204/828
# No data for Tongshan
# 205/828
# 206/828
# No data for Lishu
# 207/828
# No data for Jinji
# 208/828
# 209/828
# No data for Guozhen
# 210/828
# No data for Xishan
# 211/828
# No data for Baihe
# 212/828
# No data for Changqing
# 213/828
# 214/828
# 215/828
# No data for Shanting
# 216/828
# No data for Jijiang
# 217/828
# No data for Pingnan
# 218/828
# 219/828
# No data for Pingzhuang
# 220/828
# No data for Fuli
# 221/828
# No data for Nandu
# 222/828
# No data for Mujiayingzi
# 223/828
# 224/828
# No data for Huaidian
# 225/828
# 226/828
# 227/828
# No data for Min’an
# 228/828
# 229/828
# 230/828
# 231/828
# No data for Xiahu
# 232/828
# No data for Sanchazi
# 233/828
# 234/828
# 235/828
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-97-7c6f07b8a2c7> in <module>()
#       4 for cityName, loc in citiesList.items():
#       5     print(str(i)+"/"+str(nbCities))
# ----> 6     getWeatherForCity(cityName, loc[0], loc[1], driver, cities)
#       7     i=i+1
#       8
#
# <ipython-input-94-d395c5c90bbd> in getWeatherForCity(name, lat, long, driver, cities)
#      22
#      23     while (title == None):
# ---> 24         time.sleep(1)
#      25         content = BeautifulSoup(driver.page_source, "html.parser")
#      26         title = content.find("span", {"class":"b_prominentFocusLabel"})
#
# KeyboardInterrupt:

# %%
#saving in xls file
for i in range(0,12):
    df = pandas.DataFrame(cities[i])
    df.to_excel("RetrievedData/citiesAvrWeather"+cities[i][0]['mShort']+".xlsx",index=False, encoding="utf-8")
